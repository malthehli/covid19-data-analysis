# %%
import pandas as pd

# %%
USdata = pd.read_csv("COVID19_state.csv")

# %%
USdata.head()
# Out:
#         State    Tested  Infected  Deaths  Population  Pop Density    Gini  \
# 0      Alaska    620170     17057      84      734002       1.2863  0.4081
# 1     Alabama   1356420    194892    2973     4908621      96.9221  0.4847
# 2    Arkansas   1363429    113641    1985     3038999      58.4030  0.4719
# 3     Arizona   1792602    248139    5982     7378494      64.9550  0.4713
# 4  California  18912501    930628   17672    39937489     256.3727  0.4899
#
#    ICU Beds  Income    GDP  ...  Hospitals  Health Spending  Pollution  \
# 0       119   59687  73205  ...         21            11064        6.4
# 1      1533   42334  45219  ...        101             7281        8.1
# 2       732   42566  42454  ...         88             7408        7.1
# 3      1559   43650  48055  ...         83             6452        9.7
# 4      7338   62586  74205  ...        359             7549       12.8
#
#    Med-Large Airports  Temperature  Urban  Age 0-25  Age 26-54  Age 55+  \
# ...

# %%
USdata.shape
# Out:
# (51, 26)

# %%
USdata['Deaths'].fillna(0,inplace = True)

# %%
USdata['Deaths'].sum()
# Out:
# 222245

# %%
USdata
# Out:
#                    State    Tested  Infected  Deaths  Population  Pop Density  \
# 0                 Alaska    620170     17057      84      734002       1.2863
# 1                Alabama   1356420    194892    2973     4908621      96.9221
# 2               Arkansas   1363429    113641    1985     3038999      58.4030
# 3                Arizona   1792602    248139    5982     7378494      64.9550
# 4             California  18912501    930628   17672    39937489     256.3727
# 5               Colorado   2034795    109910    2105     5845526      56.4011
# 6            Connecticut   2367994     73858    4627     3563077     735.8689
# 7   District of Columbia    528174     17438     647      720687   11814.5410
# 8               Delaware    565983     25311     710      982895     504.3073
# 9                Florida  10126764    801371   17043    21992985     410.1256
# 10               Georgia   3596700    362921    7999    10736059     186.6719
# ...

# %%
cleanData = USdata[["State", "Tested", "Infected", "Deaths", "Population"]]

# %%
cleanData['State'].unique
# Out:
# <bound method Series.unique of 0                   Alaska
# 1                  Alabama
# 2                 Arkansas
# 3                  Arizona
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7     District of Columbia
# 8                 Delaware
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                    Iowa
# 13                   Idaho
# 14                Illinois
# 15                 Indiana
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19           Massachusetts
# 20                Maryland
# 21                   Maine
# 22                Michigan
# 23               Minnesota
# 24                Missouri
# 25             Mississippi
# 26                 Montana
# 27          North Carolina
# 28            North Dakota
# 29                Nebraska
# 30           New Hampshire
# 31              New Jersey
# 32              New Mexico
# ...

# %%
cleanData[(cleanData['Deaths'] > 10000)]['State'].unique()
# Out:
# array(['California', 'Florida', 'Illinois', 'Massachusetts', 'New Jersey',
#        'New York', 'Texas'], dtype=object)

# %%
cleanData['Infected'].sum()
# Out:
# 9160960

# %%
cleanData
# Out:
#                    State    Tested  Infected  Deaths  Population
# 0                 Alaska    620170     17057      84      734002
# 1                Alabama   1356420    194892    2973     4908621
# 2               Arkansas   1363429    113641    1985     3038999
# 3                Arizona   1792602    248139    5982     7378494
# 4             California  18912501    930628   17672    39937489
# 5               Colorado   2034795    109910    2105     5845526
# 6            Connecticut   2367994     73858    4627     3563077
# 7   District of Columbia    528174     17438     647      720687
# 8               Delaware    565983     25311     710      982895
# 9                Florida  10126764    801371   17043    21992985
# 10               Georgia   3596700    362921    7999    10736059
# 11                Hawaii    533672     15367     219     1412687
# 12                  Iowa    900994    123372    1741     3179849
# ...

# %%
cleanData.sort_values("Infected",ascending=False).head(5)
# Out:
#          State    Tested  Infected  Deaths  Population
# 4   California  18912501    930628   17672    39937489
# 43       Texas   8291703    909257   18097    29472295
# 9      Florida  10126764    801371   17043    21992985
# 34    New York  14772754    511368   25838    19440469
# 14    Illinois   7882680    429761   10093    12659682

# %%
cleanData.sort_values("Population",ascending=False).head(1)
# Out:
#         State    Tested  Infected  Deaths  Population
# 4  California  18912501    930628   17672    39937489

# %%
cleanData.sort_values("Infected",ascending=True).head(5)
# Out:
#             State  Tested  Infected  Deaths  Population
# 46        Vermont  415518      2219      58      628061
# 21          Maine  644435      6799     148     1345790
# 30  New Hampshire  626532     11320     483     1371246
# 50        Wyoming  134018     14167      87      567025
# 11         Hawaii  533672     15367     219     1412687

# %%
InfectedBystates = cleanData.groupby("State")[["Infected"]].sum()
top5Data = InfectedBystates.sort_values("Infected", ascending=False).head(5)
top5Data["Infected"].plot.pie(title = "The 5 states with the least number of infected people")

# %%
state2 = cleanData.iloc[[43, 4], [0,1]].groupby(["State"])[["Tested"]].sum()
data2 = state2.plot.bar(title = "Tested people", color = "Blue")
data2.set_xlabel("State")
data2.set_ylabel("Tested people")
# Out:
# Text(0, 0.5, 'Tested people')

# %%
datasum = cleanData[["Infected", "Deaths", "Population"]]
df1 = datasum.groupby("Population")[["Infected"]].sum()
df2 = datasum.groupby("Population")[["Deaths"]].sum()

ax = df1.plot(title = "Infected and Deaths", color="Red")

df2.plot(ax = ax, color="Blue")
ax.set_xlabel("Population")
# Out:
# Text(0.5, 0, 'Population')
